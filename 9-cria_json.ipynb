# %%
import json

# %%
dados_receita = {
    "receitas":[
        {
            "titulo": "Bolo de Chocolate",
            "tempo_preparo": "45 minutos",
            "porcoes": 8,
            "ingredientes":[
                {"ingrediente": "Farinha de Trigo", "quantidade": "2 xícaras"},
                {"ingrediente": "Açúcar", "quantidade": "1 xícaras"},
                {"ingrediente": "Ovos", "quantidade": "3 xícaras"},
                {"ingrediente": "Leite", "quantidade": "1 xícaras"},
                {"ingrediente": "Manteiga", "quantidade": "1/2 xícaras"}
            ]
        },
        {
            "titulo" : "Salada Caesar",
            "tempo_preparo": "20 minutos",
            "porcoes": 4,
            "ingredientes":[
                {"ingrediente": "Alface romana", "quantidade": "1 cabeça"},
                {"ingrediente": "Croutons", "quantidade": "1 xícaras"},
                {"ingrediente": "Queijo Parmesão", "quantidade": "1/2 xícaras"},
                {"ingrediente": "Molho caesar", "quantidade": "1/4 xícaras"}
            ]
        },
        {
            "titulo" : "Pasta ao Pesto",
            "tempo_preparo": "30 minutos",
            "porcoes": 2,
            "ingredientes":[
                {"ingrediente": "Massa", "quantidade": "200g"},
                {"ingrediente": "Manjericão Fresco", "quantidade": "1/2 xícaras"},
                {"ingrediente": "Azeite de Oliva", "quantidade": "1/3 xícaras"},
                {"ingrediente": "Nozes", "quantidade": "1/4 xícaras"},
                {"ingrediente": "Queijo Parmesão", "quantidade": "1/4 xícaras"}
            ]

        }
    ]
}

# %%
with open("dados/receita.json", "w", encoding="utf-8") as file:
    json.dump(dados_receita, file, ensure_ascii=False, indent=4)
